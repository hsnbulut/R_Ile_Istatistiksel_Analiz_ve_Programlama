# %% [markdown]
# ## **14. NORMALLİK TESTLERİ**

# %% [markdown]
# ## **14.1. Kolmogorov-Smirnov Uyum İyiliği Testi**

# %% [markdown]
# **Örnek 14.1**

# %%
set.seed(2022)
veri<-rnorm(n=100,mean = 0,sd=1)
referans<-rnorm(n=100,mean = 0,sd=1)
ks.test(x = veri,y = referans)
# Out:
# 	Asymptotic two-sample Kolmogorov-Smirnov test
#
# data:  veri and referans
# D = 0.19, p-value = 0.0541
# alternative hypothesis: two-sided

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Örnek 14.2'yi incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# **Örnek 14.2**

# %%
ks.test(x = iris$Petal.Length,"pnorm")
# Out:
# Warning message in ks.test.default(x = iris$Petal.Length, "pnorm"):
# “ties should not be present for the Kolmogorov-Smirnov test”
# 	Asymptotic one-sample Kolmogorov-Smirnov test
#
# data:  iris$Petal.Length
# D = 0.87653, p-value < 2.2e-16
# alternative hypothesis: two-sided

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Bölüm 14.2'yi incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# ## **14.2. Cramer-von Mises Uyum İyilği Testi**

# %% [markdown]
# **Örnek 14.3**

# %%
library(goftest)
cvm.test(x = veri, null = "pnorm",mean=0,sd=1,estimated = FALSE)
# Out:
# 	Cramer-von Mises test of goodness-of-fit
# 	Null hypothesis: Normal distribution
# 	with parameters mean = 0, sd = 1
# 	Parameters assumed to be fixed
#
# data:  veri
# omega2 = 0.27918, p-value = 0.1549

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Örnek 14.4'ü incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# **Örnek 14.4**

# %%
library(goftest)
cvm.test(x = iris$Petal.Length, null = "pnorm",estimated = TRUE)
# Out:
# 	Cramer-von Mises test of goodness-of-fit
# 	Braun's adjustment using 12 groups
# 	Null hypothesis: Normal distribution
# 	Parameters assumed to have been estimated from data
#
# data:  iris$Petal.Length
# omega2max = 3.9822, p-value < 2.2e-16

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Bölüm 14.3'ü incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# ## **14.3. Shapiro-Wilk Testi**

# %% [markdown]
# **Örnek 14.5**

# %%
stats::shapiro.test(veri)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  veri
# W = 0.99017, p-value = 0.678

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Örnek 14.6'yı incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# **Örnek 14.6**

# %%
stats::shapiro.test(iris$Petal.Length)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  iris$Petal.Length
# W = 0.87627, p-value = 7.412e-10

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Bölüm 14.4'ü incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# ## **14.4. Lilliefors Normallik Testi**

# %% [markdown]
# **Örnek 14.7**

# %%
library(nortest)
lillie.test(veri)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  veri
# D = 0.050909, p-value = 0.7563

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Örnek 14.8'i incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# **Örnek 14.8**

# %%
library(nortest)
lillie.test(iris$Petal.Length)
# Out:
# 	Lilliefors (Kolmogorov-Smirnov) normality test
#
# data:  iris$Petal.Length
# D = 0.19815, p-value = 7.901e-16

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Bölüm 14.5'i incelemek için kitaba geri dönebilirsin.

# %% [markdown]
# ## **14.5. Grafiklere Dayalı Normallik İncelemesi**

# %%
fitdistrplus::plotdist(veri,demp=TRUE)
# Out:
# Plot with title “Cumulative distribution”

# %%
fitdistrplus::plotdist(iris$Petal.Length,demp=TRUE)
# Out:
# Plot with title “Cumulative distribution”

# %%
qqnorm(veri)
qqline(veri,col="blue",lwd=2)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(iris$Petal.Length)
qqline(iris$Petal.Length,col="blue",lwd=2)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
fitdistrplus::descdist(data=veri)
# Out:
# summary statistics
# ------
# min:  -2.900629   max:  2.887423
# median:  0.1718658
# mean:  0.138746
# estimated sd:  1.020093
# estimated skewness:  -0.09133637
# estimated kurtosis:  3.428869
# Plot with title “Cullen and Frey graph”

# %%
fitdistrplus::descdist(data=iris$Petal.Length)
# Out:
# summary statistics
# ------
# min:  1   max:  6.9
# median:  4.35
# mean:  3.758
# estimated sd:  1.765298
# estimated skewness:  -0.2748842
# estimated kurtosis:  1.597897
# Plot with title “Cullen and Frey graph”

# %% [markdown]
# #### Kitaba geri dön!
# <img src="https://raw.githubusercontent.com/tensorchiefs/dl_book/master/imgs/Page_turn_icon_A.png" width="120" align="left" />
# Bölüm 14 tamamlandı. Bir sonraki bölümü incelemek için kitaba geri dönebilirsin.
